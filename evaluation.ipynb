# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

# %%
test = pd.read_csv("data/20220823/20220823_test.csv")['TRQ']
test = test.sample(frac=1, random_state=42).reset_index()
test.head()
# Out:
#    index     TRQ
# 0   6196  2441.0
# 1   3527  2405.0
# 2   8825  2554.0
# 3   5095  2534.0
# 4   9603  2430.0

# %%
plt.plot(test['TRQ'][:1000])
